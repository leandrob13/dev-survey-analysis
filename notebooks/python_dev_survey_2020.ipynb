# %%
import os
import requests
import pandas as pd

LOCATION = "../data/python_dev_survey.csv"

def download_file_from_google_drive():
    file_id = '1roodP07AhK1-oM3d9jcr8ffnhQO8spdn'
    URL = "https://docs.google.com/uc?export=download"
    print("Downloading file")
    return requests.get(URL, params = { 'id' : file_id }, stream = True)

def save_response_content(response):
    CHUNK_SIZE = 32768
    data_path = "../data"
    if not os.path.exists(data_path):
        os.mkdir(data_path)
    print("Writing file")
    with open(LOCATION, "wb") as f:
        for chunk in response.iter_content(CHUNK_SIZE):
            if chunk: # filter out keep-alive new chunks
                f.write(chunk)

res = download_file_from_google_drive()
save_response_content(res)
print("Done")

df = pd.read_csv(LOCATION).set_index("response_id")
df.head(10)
# Out:
# Downloading file
# Writing file
# Done
#             Is Python the main language you use for your current projects?  \
# response_id
# 10                                                         Yes
# 100                                                        Yes
# 1000                                                       Yes
# 10000                                                      Yes
# 10001                                                      NaN
# 10002                                                      NaN
# 10003                 No, I use Python as a secondary language
# 10004                                                      Yes
# 10005                                                      NaN
# 10007                                                      NaN
#
#             Bash / Shell:What other language(s) do you use?  \
# response_id
# 10                                             Bash / Shell
# 100                                                     NaN
# 1000                                                    NaN
# 10000                                          Bash / Shell
# 10001                                                   NaN
# 10002                                                   NaN
# 10003                                                   NaN
# 10004                                                   NaN
# 10005                                                   NaN
# 10007                                                   NaN
#
#             C/C++:What other language(s) do you use?  \
# response_id
# 10                                               NaN
# 100                                              NaN
# 1000                                             NaN
# 10000                                            NaN
# 10001                                            NaN
# 10002                                            NaN
# 10003                                            NaN
# 10004                                            NaN
# 10005                                            NaN
# 10007                                            NaN
#
#             C#:What other language(s) do you use?  \
# response_id
# 10                                            NaN
# 100                                           NaN
# 1000                                          NaN
# 10000                                         NaN
# 10001                                         NaN
# 10002                                         NaN
# 10003                                         NaN
# 10004                                         NaN
# 10005                                         NaN
# 10007                                         NaN
#
#             Clojure:What other language(s) do you use?  \
# response_id
# 10                                                 NaN
# 100                                                NaN
# 1000                                               NaN
# 10000                                              NaN
# 10001                                              NaN
# 10002                                              NaN
# 10003                                              NaN
# 10004                                              NaN
# 10005                                              NaN
# 10007                                              NaN
#
#             CoffeeScript:What other language(s) do you use?  \
# response_id
# 10                                                      NaN
# 100                                                     NaN
# 1000                                                    NaN
# 10000                                                   NaN
# 10001                                                   NaN
# 10002                                                   NaN
# 10003                                                   NaN
# 10004                                                   NaN
# 10005                                                   NaN
# 10007                                                   NaN
#
#             Go:What other language(s) do you use?  \
# response_id
# 10                                            NaN
# 100                                           NaN
# 1000                                          NaN
# 10000                                         NaN
# 10001                                         NaN
# 10002                                         NaN
# 10003                                         NaN
# 10004                                         NaN
# 10005                                         NaN
# 10007                                         NaN
#
#             Groovy:What other language(s) do you use?  \
# response_id
# 10                                                NaN
# 100                                               NaN
# 1000                                              NaN
# 10000                                             NaN
# 10001                                             NaN
# 10002                                             NaN
# 10003                                             NaN
# 10004                                             NaN
# 10005                                             NaN
# 10007                                             NaN
#
#             HTML/CSS:What other language(s) do you use?  \
# response_id
# 10                                             HTML/CSS
# 100                                                 NaN
# 1000                                                NaN
# 10000                                               NaN
# 10001                                               NaN
# 10002                                               NaN
# 10003                                               NaN
# 10004                                          HTML/CSS
# 10005                                               NaN
# 10007                                               NaN
#
#             Java:What other language(s) do you use?  ...  \
# response_id                                          ...
# 10                                              NaN  ...
# 100                                             NaN  ...
# 1000                                            NaN  ...
# 10000                                           NaN  ...
# 10001                                           NaN  ...
# 10002                                           NaN  ...
# 10003                                           NaN  ...
# 10004                                           NaN  ...
# 10005                                           NaN  ...
# 10007                                           NaN  ...
#
#             Product manager:Which of the following best describes your job role(s)?  \
# response_id
# 10                                                         NaN
# 100                                                        NaN
# 1000                                                       NaN
# 10000                                                      NaN
# 10001                                                      NaN
# 10002                                                      NaN
# 10003                                                      NaN
# 10004                                                      NaN
# 10005                                                      NaN
# 10007                                                      NaN
#
#             QA engineer:Which of the following best describes your job role(s)?  \
# response_id
# 10                                                         NaN
# 100                                                        NaN
# 1000                                                       NaN
# 10000                                                      NaN
# 10001                                                      NaN
# 10002                                                      NaN
# 10003                                                      NaN
# 10004                                                      NaN
# 10005                                                      NaN
# 10007                                                      NaN
#
#             Systems analyst:Which of the following best describes your job role(s)?  \
# response_id
# 10                                                         NaN
# 100                                                        NaN
# 1000                                                       NaN
# 10000                                                      NaN
# 10001                                                      NaN
# 10002                                                      NaN
# 10003                                                      NaN
# 10004                                                      NaN
# 10005                                                      NaN
# 10007                                                      NaN
#
#             Team lead:Which of the following best describes your job role(s)?  \
# response_id
# 10                                                         NaN
# 100                                                        NaN
# 1000                                                       NaN
# 10000                                                      NaN
# 10001                                                      NaN
# 10002                                                      NaN
# 10003                                                      NaN
# 10004                                                Team lead
# 10005                                                      NaN
# 10007                                                      NaN
#
#             Technical support:Which of the following best describes your job role(s)?  \
# response_id
# 10                                                         NaN
# 100                                                        NaN
# 1000                                                       NaN
# 10000                                                      NaN
# 10001                                                      NaN
# 10002                                                      NaN
# 10003                                                      NaN
# 10004                                                      NaN
# 10005                                                      NaN
# 10007                                                      NaN
#
#             Technical writer:Which of the following best describes your job role(s)?  \
# response_id
# 10                                                         NaN
# 100                                                        NaN
# 1000                                                       NaN
# 10000                                                      NaN
# 10001                                                      NaN
# 10002                                                      NaN
# 10003                                                      NaN
# 10004                                                      NaN
# 10005                                                      NaN
# 10007                                                      NaN
#
#             Which of the following industries best describes your company's business?  \
# response_id
# 10               Information Technology / Software Development
# 100                 Banking / Real Estate / Mortgage Financing
# 1000             Information Technology / Software Development
# 10000                                                      NaN
# 10001                                                      NaN
# 10002                                                      NaN
# 10003                                                      NaN
# 10004                                                    Other
# 10005                                                      NaN
# 10007                                                      NaN
#
#             Which of the following industries do you develop for?  \
# response_id
# 10               Information Technology / Software Development
# 100                                                        NaN
# 1000             Information Technology / Software Development
# 10000                                                      NaN
# 10001                                                      NaN
# 10002                                                      NaN
# 10003                                                      NaN
# 10004                                                      NaN
# 10005                                                      NaN
# 10007                                                      NaN
#
#             Could you tell us your age range? What country do you live in?
# response_id
# 10                                      30–39                       Canada
# 100                                     30–39                United States
# 1000                                    21–29                United States
# 10000                                     NaN                          NaN
# 10001                                     NaN                          NaN
# 10002                                     NaN                          NaN
# 10003                                     NaN                          NaN
# 10004                                   30–39                       Poland
# 10005                                     NaN                          NaN
# 10007                                     NaN                          NaN
#
# [10 rows x 289 columns]

# %%
cols = [
    'Is Python the main language you use for your current projects?', 
    'How long have you been programming in Python?', 
    'How many years of professional coding experience do you have?', 
    'For what purposes do you mainly use Python?', 
    'Data analysis: What do you use Python for?', 
    'Machine learning: What do you use Python for?', 
    'Data analysis:To what extent are you involved in the following activities?', 
    'Machine learning:To what extent are you involved in the following activities?', 
    'What do you use Python for the most?', 
    'What is your employment status?', 
    'Could you tell us your age range?', 
    'What country do you live in?'
]

new_df = df[cols].copy().dropna(how="all")
new_df.head(10)
# Out:
#             Is Python the main language you use for your current projects?  \
# response_id
# 10                                                         Yes
# 100                                                        Yes
# 1000                                                       Yes
# 10000                                                      Yes
# 10003                 No, I use Python as a secondary language
# 10004                                                      Yes
# 10008                                                      Yes
# 1001                                                       Yes
# 10010                                                      Yes
# 10011                                                      Yes
#
#             How long have you been programming in Python?  \
# response_id
# 10                                             6–10 years
# 100                                             3–5 years
# 1000                                            3–5 years
# 10000                                           1–2 years
# 10003                                           3–5 years
# 10004                                           11+ years
# 10008                                           3–5 years
# 1001                                            3–5 years
# 10010                                           3–5 years
# 10011                                           3–5 years
#
#             How many years of professional coding experience do you have?  \
# response_id
# 10                                                   11+ years
# 100                                                  1–2 years
# 1000                                                 3–5 years
# 10000                                         Less than 1 year
# 10003                                                1–2 years
# 10004                                               6–10 years
# 10008                                               6–10 years
# 1001                                                 11+ years
# 10010                                               6–10 years
# 10011                                                1–2 years
#
#              For what purposes do you mainly use Python?  \
# response_id
# 10                            Both for work and personal
# 100                                             For work
# 1000                          Both for work and personal
# 10000        For personal, educational  or side projects
# 10003        For personal, educational  or side projects
# 10004                         Both for work and personal
# 10008                         Both for work and personal
# 1001                                            For work
# 10010                         Both for work and personal
# 10011                         Both for work and personal
#
#             Data analysis: What do you use Python for?  \
# response_id
# 10                                                 NaN
# 100                                                NaN
# 1000                                     Data analysis
# 10000                                    Data analysis
# 10003                                    Data analysis
# 10004                                              NaN
# 10008                                    Data analysis
# 1001                                     Data analysis
# 10010                                    Data analysis
# 10011                                              NaN
#
#             Machine learning: What do you use Python for?  \
# response_id
# 10                                                    NaN
# 100                                                   NaN
# 1000                                     Machine learning
# 10000                                                 NaN
# 10003                                                 NaN
# 10004                                                 NaN
# 10008                                                 NaN
# 1001                                                  NaN
# 10010                                                 NaN
# 10011                                                 NaN
#
#             Data analysis:To what extent are you involved in the following activities?  \
# response_id
# 10                                                         NaN
# 100                                                        NaN
# 1000                                        secondary activity
# 10000                                                      NaN
# 10003                                       secondary activity
# 10004                                                      NaN
# 10008                                                    hobby
# 1001                                          primary activity
# 10010                                       secondary activity
# 10011                                                      NaN
#
#             Machine learning:To what extent are you involved in the following activities?  \
# response_id
# 10                                                         NaN
# 100                                                        NaN
# 1000                                          primary activity
# 10000                                                      NaN
# 10003                                                      NaN
# 10004                                                      NaN
# 10008                                                      NaN
# 1001                                                       NaN
# 10010                                                      NaN
# 10011                                                      NaN
#
#                           What do you use Python for the most?  \
# response_id
# 10                                             Web development
# 100                                                        NaN
# 1000                                          Machine learning
# 10000                                                      NaN
# 10003                                                      NaN
# 10004                                          Web development
# 10008        DevOps / System administration / Writing autom...
# 1001                                             Data analysis
# 10010                                            Data analysis
# 10011                                          Web development
#
#                                What is your employment status?  \
# response_id
# 10                  Fully employed by a company / organization
# 100                 Fully employed by a company / organization
# 1000                Fully employed by a company / organization
# 10000                                                      NaN
# 10003                                                      NaN
# 10004        Self-employed <em>(a person earning income dir...
# 10008               Fully employed by a company / organization
# 1001                                                       NaN
# 10010               Fully employed by a company / organization
# 10011                                                      NaN
#
#             Could you tell us your age range? What country do you live in?
# response_id
# 10                                      30–39                       Canada
# 100                                     30–39                United States
# 1000                                    21–29                United States
# 10000                                     NaN                          NaN
# 10003                                     NaN                          NaN
# 10004                                   30–39                       Poland
# 10008                                   40–49                United States
# 1001                                      NaN                          NaN
# 10010                                   40–49                United States
# 10011                                     NaN                          NaN

# %%
import functools as ft

cleaned = pd.DataFrame(index=["response_id"])

picked = ["Data analysis", "Machine learning"]
chosen_mask = ft.reduce(
    lambda a, b: a | (new_df[f"{b}: What do you use Python for?"].notna()), 
    picked, 
    False
)
activity_mask = ft.reduce(
    lambda a, b: a | (
        new_df[f"{b}:To what extent are you involved in the following activities?"]
            .str.contains("primary|secondary", na=False, regex=True)
    ), 
    picked, 
    False
)
purpose_mask = (
    new_df["For what purposes do you mainly use Python?"]
        .str.contains("work", na=False, regex=True)
)

cleaned = new_df[chosen_mask & activity_mask & purpose_mask]
cleaned
# Out:
#             Is Python the main language you use for your current projects?  \
# response_id
# 1000                                                       Yes
# 1001                                                       Yes
# 10010                                                      Yes
# 10017                                                      Yes
# 10019                                                      Yes
# ...                                                        ...
# 9985                                                       Yes
# 9986                                                       Yes
# 999                   No, I use Python as a secondary language
# 9991                                                       Yes
# 9998                                                       Yes
#
#             How long have you been programming in Python?  \
# response_id
# 1000                                            3–5 years
# 1001                                            3–5 years
# 10010                                           3–5 years
# 10017                                           11+ years
# 10019                                           1–2 years
# ...                                                   ...
# 9985                                            3–5 years
# 9986                                            1–2 years
# 999                                             11+ years
# 9991                                            3–5 years
# 9998                                           6–10 years
#
#             How many years of professional coding experience do you have?  \
# response_id
# 1000                                                 3–5 years
# 1001                                                 11+ years
# 10010                                               6–10 years
# 10017                                                11+ years
# 10019                                                11+ years
# ...                                                        ...
# 9985                                                6–10 years
# 9986                                                 3–5 years
# 999                                                  11+ years
# 9991                                                 3–5 years
# 9998                                                6–10 years
#
#             For what purposes do you mainly use Python?  \
# response_id
# 1000                         Both for work and personal
# 1001                                           For work
# 10010                        Both for work and personal
# 10017                        Both for work and personal
# 10019                        Both for work and personal
# ...                                                 ...
# 9985                         Both for work and personal
# 9986                         Both for work and personal
# 999                                            For work
# 9991                         Both for work and personal
# 9998                         Both for work and personal
#
#             Data analysis: What do you use Python for?  \
# response_id
# 1000                                     Data analysis
# 1001                                     Data analysis
# 10010                                    Data analysis
# 10017                                    Data analysis
# 10019                                    Data analysis
# ...                                                ...
# 9985                                     Data analysis
# 9986                                     Data analysis
# 999                                                NaN
# 9991                                     Data analysis
# 9998                                     Data analysis
#
#             Machine learning: What do you use Python for?  \
# response_id
# 1000                                     Machine learning
# 1001                                                  NaN
# 10010                                                 NaN
# 10017                                    Machine learning
# 10019                                    Machine learning
# ...                                                   ...
# 9985                                     Machine learning
# 9986                                     Machine learning
# 999                                      Machine learning
# 9991                                     Machine learning
# 9998                                     Machine learning
#
#             Data analysis:To what extent are you involved in the following activities?  \
# response_id
# 1000                                        secondary activity
# 1001                                          primary activity
# 10010                                       secondary activity
# 10017                                         primary activity
# 10019                                         primary activity
# ...                                                        ...
# 9985                                          primary activity
# 9986                                        secondary activity
# 999                                                        NaN
# 9991                                          primary activity
# 9998                                          primary activity
#
#             Machine learning:To what extent are you involved in the following activities?  \
# response_id
# 1000                                          primary activity
# 1001                                                       NaN
# 10010                                                      NaN
# 10017                                         primary activity
# 10019                                       secondary activity
# ...                                                        ...
# 9985                                          primary activity
# 9986                                          primary activity
# 999                                           primary activity
# 9991                                          primary activity
# 9998                                          primary activity
#
#             What do you use Python for the most?  \
# response_id
# 1000                            Machine learning
# 1001                               Data analysis
# 10010                              Data analysis
# 10017                           Machine learning
# 10019                              Data analysis
# ...                                          ...
# 9985                            Machine learning
# 9986                            Machine learning
# 999                             Machine learning
# 9991                               Data analysis
# 9998                             Web development
#
#                                What is your employment status?  \
# response_id
# 1000                Fully employed by a company / organization
# 1001                                                       NaN
# 10010               Fully employed by a company / organization
# 10017               Fully employed by a company / organization
# 10019               Fully employed by a company / organization
# ...                                                        ...
# 9985                Fully employed by a company / organization
# 9986                Fully employed by a company / organization
# 999                 Fully employed by a company / organization
# 9991                Fully employed by a company / organization
# 9998         Freelancer <em>(a person pursuing a profession...
#
#             Could you tell us your age range? What country do you live in?
# response_id
# 1000                                    21–29                United States
# 1001                                      NaN                          NaN
# 10010                                   40–49                United States
# 10017                                   50–59                United States
# 10019                                   50–59                      Belgium
# ...                                       ...                          ...
# 9985                                    30–39               Czech Republic
# 9986                                    21–29                      Armenia
# 999                                     30–39                      Finland
# 9991                                    21–29                    Australia
# 9998                                    30–39                        Spain
#
# [13519 rows x 12 columns]

# %%
from matplotlib import pyplot as plt 

def age_grouper(idx):
    older = ["30–39", "40–49", "50–59", "60 or older"]
    return "Above Age 30" if idx in older else "Below Age 30"

def get_subplots():
    ax1 = plt.subplot(1, 2, 1)
    ax2 = plt.subplot(1, 2, 2, sharey=ax1)
    ax1.set_yticks([])
    ax1.set_ylabel('Developer %')
    ax1.set_title('Developers by Age Ranges', fontsize=14)
    ax2.set_title('Developers Above or Below 30', fontsize=14)

    return ax1, ax2

def set_values_in_bars(axis_list):
    for ax in axis_list:
        for patch in ax.patches:
            height = patch.get_height()
            ax.annotate(
                f'{height}',
                xy=(patch.get_x() + patch.get_width() / 2, height),
                xytext=(0, 3), 
                textcoords="offset points",
                ha='center', va='bottom', fontsize=12
            )

# %%
# %matplotlib inline

axis1, axis2 = get_subplots()
counts = (
    cleaned['Could you tell us your age range?']
      .value_counts(normalize=True)
      .map(lambda x: float('{:,.2f}'.format(x * 100)))
      .sort_index()
)
counts.plot(kind="bar", rot=0, ax=axis1, width = 0.75)
counts.groupby(age_grouper).agg('sum').plot(kind="bar", rot=0, ax=axis2, figsize=(12, 7))
set_values_in_bars([axis1, axis2])
fig = axis1.get_figure()
fig.suptitle('Age Distribution of Data Analysts and Machine Learning Developers', fontsize=16)

#plt.savefig("chart1.png")
# Out:
# Text(0.5, 0.98, 'Age Distribution of Data Analysts and Machine Learning Developers')

# %%
countries = cleaned['What country do you live in?']
country_counts = (
    countries
      .value_counts(normalize=True)
      .map(lambda x: x * 100)
)

grouped_countries = country_counts[country_counts < 0.5].index.values
grouped_counts = (
    country_counts
      .groupby(lambda idx: idx if idx not in grouped_countries else "Other")
      .agg('sum')
      .sort_values()
)
axis = grouped_counts.plot(kind="barh", figsize=(13, 15), width = 0.8, fontsize=13)
axis.set_xlabel('Developer %')

print("Total number of countries: ", len(countries.value_counts()))
print("Total devs: ", countries.value_counts().sum())

for i, v in enumerate(grouped_counts):
    plt.text(v + 0.1, i, str(round(v, 2)), color='steelblue', va="center")
# Out:
# Total number of countries:  91
# Total devs:  11114
